# %%
import pandas as pd
import re
import nltk
import string
import google_conf
from importlib import reload
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.style.use('seaborn-white')
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams['font.size'] = 8

def save_figure(fig, fig_name):
    fig.savefig("../figures/" + fig_name + ".tiff")
    fig.savefig("../figures/" + fig_name + ".png")
# Out:
# /var/folders/zg/zvg9y3rs7j527jxfq9sc2xqc0000gn/T/ipykernel_4724/1576836852.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
pop_data = google_conf.setup(sheet_url="https://docs.google.com/spreadsheets/d/1o8L0Rt4CzQ_DcYdaKgCdige4nJs0sydlTGiMBSstQtc/edit?usp=sharing", service_account_path="../../ServiceAccountsKey.json")

# %%
articles_metadata = pd.read_json("../data/article_metadata.json")
articles_metadata.head(5)
# Out:
#    pop_id  year                 authors                            journal  \
# 0       0  2011              Bos et al.            Political Communication
# 1       1  2019         Blassnig et al.            Political Communication
# 2       2  2017                Caramani  American Political Science Review
# 3       3  2020  Wuttke,Schimpf, Schoen  American Political Science Review
# 4       4  2014                   Treib  Journal of European Public Policy
#
#                                                title     type  \
# 0  How the Media Shape Perceptions of Right-Wing ...  article
# 1  Hitting a Nerve: Populist News Articles Lead t...  article
# 2  Will vs. Reason: The Populist and Technocratic...  article
# 3  When the Whole Is Greater than the Sum of Its ...  article
# 4  The voter says no, but nobody listens: causes ...  article
#
#                                             filepath
# 0  Political Communication/2011 - Bos et al. - Ho...
# 1  Political Communication/2019 - Blassing et al....
# 2  American Political Science Review/2017 - Caram...
# 3  American Political Science Review/2020 - Wuttk...
# 4  Journal of European Public Policy/2014 - Treib...

# %%
articles_metadata = articles_metadata[articles_metadata["filepath"].apply(bool)].copy()

# %%
sample_pop_ids = [62, 377, 188, 364, 499, 228, 376, 90, 227, 330]

# %% [markdown]
# # Test with one document

# %%
pop_id = 90
path = "../data/large_data/articles_filteredtexts/"
filename = "filteredtext_pop_id_{}.txt".format(str(pop_id))

# %%
with open(path + filename, "r") as f:
    filteredtext = f.read()

# %%
test_str_list = filteredtext.split()[:100]
print(test_str_list)
# Out:
# ['European', 'Journal', 'of', 'Political', 'Research', '59:', '3–24,', '2020', '3', 'The', 'effects', 'of', 'populism', 'as', 'a', 'social', 'identity', 'frame', 'on', 'persuasion', 'and', 'mobilisation:', 'Evidence', 'from', 'a', '15-country', 'experiment', 'LINDA', 'BOS,', 'CHRISTIAN', 'SCHEMER,', 'NICOLETA', 'CORBU,', 'MICHAEL', 'HAMELEERS,', 'IOANNIS', 'ANDREADIS,', 'ANNE', 'SCHULZ,', 'DESIRÉE', 'SCHMUCK,', 'CARSTEN', 'REINEMANN7', '&', 'NAYLA', 'FAWZI7', '1University', 'of', 'Amsterdam,', 'The', 'Netherlands;', '2Johannes', 'Gutenberg', 'University,', 'Mainz,', 'Germany;', '3National', 'University', 'of', 'Political', 'Studies', 'and', 'Public', 'Administration,', 'Bucharest,', 'Romania;', '4Aristotle', 'University', 'of', 'Thessaloniki,', 'Greece;', '5University', 'of', 'Zürich,', 'Switzerland;', '6University', 'of', 'Vienna,', 'Austria;', '7Ludwig-Maximilians-University', 'Munich,', 'Germany', 'Abstract.', 'This', 'article', 'investigates', 'the', 'impact', 'of', 'populist', 'messages', 'on', 'issue', 'agreement', 'and', 'readiness', 'for', 'action', 'in', '15']

# %% [markdown]
# # populis* usage overview

# %%
# gather indeces:
filteredtext_split = filteredtext.split()
inxs = [t[0] for t in enumerate(filteredtext_split) if re.search("populis", t[1], re.IGNORECASE)]
inxs
# Out:
# [12,
#  89,
#  105,
#  134,
#  164,
#  246,
#  250,
#  296,
#  319,
#  342,
#  521,
#  548,
#  554,
#  582,
#  604,
#  645,
#  680,
#  705,
#  732,
#  778,
#  812,
#  933,
#  943,
#  978,
#  1013,
#  1074,
#  1082,
#  1098,
#  1111,
#  1125,
#  1168,
#  1197,
#  1278,
#  1334,
#  1340,
#  1362,
#  1375,
#  1438,
#  1458,
#  1644,
#  1676,
#  1730,
#  1755,
#  1787,
#  1807,
#  1860,
#  1883,
#  1907,
#  1956,
#  1993,
#  2019,
#  2091,
#  2196,
#  2225,
#  2235,
#  2284,
#  2402,
#  2414,
#  2427,
#  2452,
#  2501,
#  2506,
#  2534,
#  2549,
#  2569,
#  2588,
#  2601,
#  2611,
#  2630,
#  2644,
#  2720,
#  2744,
#  2835,
#  3009,
#  3083,
#  3118,
#  3150,
#  3388,
#  3425,
#  3492,
#  3514,
#  3654,
#  3675,
#  3722,
#  3759,
#  4259,
#  4481,
#  4524,
#  4565,
#  4925,
#  4953,
#  5337,
#  5527,
#  5722,
#  5865,
#  6133,
#  6172,
#  6201,
#  6273,
#  6383,
#  6414,
#  6437,
#  6458,
#  6562,
#  6615,
#  6632,
#  6708,
#  6858,
#  6923,
#  7292,
#  7333,
#  7341,
#  7355,
#  7369,
#  7506,
#  7518,
#  7595,
#  7744,
#  7747,
#  7771,
#  7876,
#  7900,
#  7913,
#  7946,
#  7957,
#  8006]

# %%
for i in inxs:
    print(filteredtext_split[i-2:i+3])
# Out:
# ['effects', 'of', 'populism', 'as', 'a']
# ['impact', 'of', 'populist', 'messages', 'on']
# ['7,).', 'Specifically,', 'populist', 'communicators', 'rely']
# ['is', 'called', '‘populist', 'identity', 'framing’']
# ['ordinary', 'people,', 'populist', 'communicators', 'engage']
# ['of', 'the', 'populist', 'identity', 'frames.']
# ['frames.', 'Keywords:', 'populism;', 'social', 'identity']
# ['(Mudde', '2004),', 'populist', 'messages', 'can']
# ['Turner', '1986),', 'populist', 'rhetoric', 'frames']
# ['to', 'this', 'populist', 'identity', 'frame']
# ['of', 'the', 'populist', 'message', '(Mudde']
# ['with', 'stronger', 'populist', 'attitudes', 'are']
# ['attracted', 'to', 'populist', 'parties', '(Akkerman']
# ['of', 'a', 'populist', 'party', '(Van']
# ['supportive', 'of', 'populism', '(Rico', 'et']
# ['other', 'words,', 'populism', 'not', 'only']
# ['component', 'of', 'populism', '(e.g.,', 'Busby']
# ['aspect', 'of', 'populist', 'rhetoric', 'on']
# ['consequences', 'of', 'populism', 'as', 'a']
# ['implications', 'of', 'populist', 'identity', 'frames']
# ['effects', 'of', 'populist', 'identity', 'framing']
# ['deprived.', 'Theory', 'Populist', 'communication', 'as']
# ['idea', 'of', 'populist', 'communication', 'emphasises']
# ['In', 'right-wing', 'populism,', 'this', 'core']
# ['This', 'central', 'populist', 'message', 'is']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['5', 'is', 'populism', 'regarded', 'as']
# ['approach', 'to', 'populist', 'communication', 'thus']
# ['approaches', 'to', 'populism', '(Hawkins', '2010;']
# ['thinideology,', 'of', 'populism', 'is', 'disseminated']
# ['elements', 'of', 'populist', 'communication', '(see']
# ['mechanisms', 'underlying', 'populist', 'communication', '(e.g.,']
# ['of', 'SIT,', 'populist', 'communication', 'invites']
# ['process', 'underlying', 'populist', 'communication', 'can']
# ['regarded', 'as', 'populist', 'identity', 'framing']
# ['effects', 'of', 'populist', 'in-group', 'cues']
# ['focus', 'of', 'populists', 'is', 'dependent']
# ['with', 'a', 'populist', 'identity', 'frame']
# ['fostered', 'by', 'populist', 'communication', 'increases']
# ['context', 'of', 'populist', 'communication,', 'Hameleers']
# ['recipients', 'of', 'populist', 'messages', 'blaming']
# ['differently,', 'when', 'populist', 'actors', 'point']
# ['share', 'the', 'populist', 'source’s', 'group-membership']
# ['issue', 'positions', 'populist', 'messages', 'suggest.']
# ['together,', 'when', 'populist', 'actors', 'bring']
# ['identity', 'framing,', 'populism’s', 'cultivation', 'of']
# ['of', 'threat,', 'populist', 'communication', 'offers']
# ['cues', 'in', 'populist', 'communication', '(the']
# ['should', 'become.', 'Populist', 'communication', 'should']
# ['cues', '(right-wing', 'populism)', 'will', 'result']
# ['effects', 'of', 'populist', 'identity', 'framing']
# ['politicised.', 'The', 'populist', 'identity', 'frame']
# ['to', 'the', 'populist', 'identity', 'frame.']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['more', 'fundamentally,', 'populist', 'political', 'communication']
# ['Walgrave', '2007),', 'populist', 'political', 'communication']
# ['2017).', 'Integrating', 'populist', 'communication', 'and']
# ['hypothesised', 'that', 'populist', 'identity', 'framing']
# ['Exposure', 'to', 'populist', 'identity', 'framing']
# ['by', 'discussing', 'populist', 'communication', 'with']
# ['combined', 'with', 'populism’s', 'core', 'anti-elitist']
# ['message', '(right-wing', 'populism),', 'the', 'threat']
# ['cues', '(right-wing', 'populism;', 'H2c).', 'Perceived']
# ['susceptible', 'to', 'populist', 'identity', 'framing']
# ['by', 'the', 'populist', 'message', 'we']
# ['success', 'of', 'populism', '(Elchardus', '&']
# ['al.', '2016).While', 'populist', 'attitudes', 'and']
# ['voters', 'support', 'populist', 'parties,', '(e.g.,']
# ['to', 'the', 'populist', 'message', 'we']
# ['not', 'all', 'populist', 'voters', 'are']
# ['in', 'a', 'populist', 'message.', 'In']
# ['susceptibility', 'to', 'populism', '(Elchardus', '&']
# ['persuasiveness', 'of', 'populist', 'identity', 'framing,']
# ['or', 'culture,', 'populist', 'actors', 'increase']
# ['onto', 'others,', 'populist', 'communication', 'facilitates']
# ['and', 'antiimmigrant', 'populist', 'identity', 'frames']
# ['response', 'to', 'populist', 'identity', 'frames.']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['resonate', 'with', 'populist', 'identity', 'frames,']
# ['and', 'anti-immigrant', 'populist', 'identity', 'cues']
# ['effect', 'of', 'populist', 'identity', 'framing']
# ['idea', 'that', 'populist', 'movements', 'and']
# ['familiar', 'with', 'populist', 'communication', 'in']
# ['effects', 'of', 'populist', 'communication', 'in']
# ['of', 'any', 'populist', 'communication', 'effects']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['typology', 'of', 'populist', 'communication', 'as']
# ['thus', 'manipulating', 'populism', 'as', 'a']
# ['The', 'rightwing', 'populist', 'condition', 'differentiated']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['(4)', 'Right-wing', 'populism', 'to', '7,']
# ['use', 'of', 'populist', 'identity', 'frames']
# ['of', 'the', 'populist', 'identity', 'frames']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['impact', 'of', 'populist', 'identity', 'frames.']
# ['study', 'of', 'populism', 'is,', 'ultimately,']
# ['experiments', 'on', 'populism', 'ever', 'conducted']
# ['two', 'different', 'populist', 'identity', 'frames,for']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['use', 'of', 'populist', 'identity', 'frames']
# ['research', 'on', 'populist', 'communication', '(Hameleers']
# ['Queller', '2000).', 'Populist', 'messages', 'that']
# ['persuasive.', 'Whether', 'populists', 'can', 'lure']
# ['effect', 'of', 'populist', 'identity', 'frames']
# ['support', 'of', 'populism.', 'When', 'it']
# ['to', 'anti-elitist', 'populist', 'identity', 'frames']
# ['the', 'anti-immigrant', 'populist', 'identity', 'frame']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']
# ['as', '‘too', 'populist’.', 'Finally,', 'these']
# ['multitude', 'of', 'populist', 'messages', 'could']
# ['factors', 'conditioning', 'populist', 'communication', 'effects.']
# ['that', 'the', 'populist', 'exclusionary', 'frame']
# ['that', 'the', 'populist', 'identity', 'frame']
# ['addition,', 'some', 'populist', 'identity', 'frames']
# ['susceptible', 'to', 'populist', 'messages', 'and']
# ['manipulation', 'of', 'populism', 'may', 'be']
# ['manipulation', 'of', 'populism', 'as', 'a']
# ['effects', 'of', 'populist', 'communication.', 'Considering']
# ['communication.', 'Considering', 'populism’s', 'political', 'relevance,']
# ['shown', 'that', 'populism', 'is', 'present']
# ['engaged', 'by', 'populist', 'communication.In', 'the']
# ['may', 'use', 'populist', 'identity', 'cues']
# ['of', 'many', 'populist', 'movements', 'around']
# ['IS1308', 'on', '‘Populist', 'Political', 'Communication']
# ['Mediated', 'Political', 'Populism', 'for', 'Democratic']
# ['EFFECTS', 'OF', 'POPULISM', 'AS', 'A']

# %%
def extract_indeces(pop_id):
    path = "../data/large_data/articles_filteredtexts/"
    filename = "filteredtext_pop_id_{}.txt".format(str(pop_id))
    with open(path + filename, "r") as f:
        filteredtext = f.read()
    filteredtext_split = filteredtext.split()
    inxs = [t[0] for t in enumerate(filteredtext_split) if re.search("populis", t[1], re.IGNORECASE)]
    return inxs
articles_metadata["populism_inxs"] = articles_metadata["pop_id"].apply(extract_indeces)

# %%
articles_metadata["populism_inxs"]
# Out:
# 0      [30, 66, 104, 122, 160, 263, 284, 310, 314, 31...
# 1      [26, 35, 64, 73, 124, 133, 150, 159, 214, 238,...
# 2      [19, 42, 57, 97, 138, 163, 377, 504, 579, 671,...
# 3      [65, 125, 142, 195, 225, 254, 282, 304, 313, 3...
# 4              [296, 2412, 4038, 4146, 4596, 4638, 4759]
#                              ...
# 536                               [155, 238, 2478, 3747]
# 537    [25, 516, 526, 534, 556, 752, 1169, 1203, 1216...
# 538    [7, 51, 97, 316, 386, 392, 452, 649, 660, 720,...
# 539    [4, 59, 195, 217, 258, 878, 905, 1029, 1570, 2...
# 540    [16, 22, 26, 80, 95, 109, 114, 131, 153, 162, ...
# Name: populism_inxs, Length: 539, dtype: object

# %%
articles_metadata["populis*_N"] = articles_metadata["populism_inxs"].apply(len)

# %%
articles_metadata["populis*_N"].sum()
# Out:
# 42174

# %%
replace_tups = [
    ("populists", "populis*"),
    ("populisms", "populis*"),
    ("populist", "populis*"),
    ("populism", "populis*"),
]
def clean_conc(conc_string):
    conc_cleaned = " ".join([re.sub("\W", "", w, count=10) for w in conc_string.lower().split()])
    conc_cleaned = re.sub("\d+", "", conc_cleaned, count=10)
    #conc_cleaned = conc_cleaned.lower().translate(str.maketrans("", "", string.punctuation))
    for tup in replace_tups:
        conc_cleaned = conc_cleaned.replace(tup[0], tup[1])
    return conc_cleaned

# %%
clean_conc("4right-wing populists.12@#`^&")
# Out:
# 'rightwing populis*'

# %%
def get_concordance(row, left=1, right=1):
    pop_id = row["pop_id"]
    path = "../data/large_data/articles_filteredtexts/"
    filename = "filteredtext_pop_id_{}.txt".format(str(pop_id))
    with open(path + filename, "r") as f:
        filteredtext = f.read()
    filteredtext_split = filteredtext.split()
    inxs = row["populism_inxs"]
    conc_data = [clean_conc(" ".join(filteredtext_split[i-left: i+right+1])) for i in inxs]
    return conc_data

# %%
articles_metadata["conc_left1"] = articles_metadata.apply(lambda row: get_concordance(row, left=1, right=0), axis=1)
articles_metadata["conc_right1"] = articles_metadata.apply(lambda row: get_concordance(row, left=0, right=1), axis=1)

# %%
articles_metadata
# Out:
#      pop_id  year                 authors  \
# 0         0  2011              Bos et al.
# 1         1  2019         Blassnig et al.
# 2         2  2017                Caramani
# 3         3  2020  Wuttke,Schimpf, Schoen
# 4         4  2014                   Treib
# ..      ...   ...                     ...
# 536     536  2018          Grzymala-Busse
# 537     537  2017             Eichengreen
# 538     538  2014                   Mudde
# 539     539  2020                    Cano
# 540     540  2015                Lindgren
#
#                                    journal  \
# 0                  Political Communication
# 1                  Political Communication
# 2        American Political Science Review
# 3        American Political Science Review
# 4        Journal of European Public Policy
# ..                                     ...
# 536                        Current History
# 537                        Current History
# 538                        Current History
# 539             European History Quarterly
# 540  Japanese Journal of Political Science
#
#                                                  title     type  \
# 0    How the Media Shape Perceptions of Right-Wing ...  article
# 1    Hitting a Nerve: Populist News Articles Lead t...  article
# 2    Will vs. Reason: The Populist and Technocratic...  article
# 3    When the Whole Is Greater than the Sum of Its ...  article
# 4    The voter says no, but nobody listens: causes ...  article
# ..                                                 ...      ...
# 536                      Poland’s Path to Illiberalism  article
# 537             The Populist Turn in American Politics  article
# 538           The Far Right and the European Elections  article
# 539                                Printing the People  article
# 540  Developing Japanese Populism Research through ...  article
#
#                                               filepath  \
# 0    Political Communication/2011 - Bos et al. - Ho...
# 1    Political Communication/2019 - Blassing et al....
# 2    American Political Science Review/2017 - Caram...
# 3    American Political Science Review/2020 - Wuttk...
# 4    Journal of European Public Policy/2014 - Treib...
# ..                                                 ...
# 536  Current History/2018 - Grzymala-Busse - Poland...
# 537  Current History/2017 - Eichengreen - The Popul...
# 538  Current History/2014 - Mudde - The Far Right a...
# 539  European History Quarterly/2020 - Cano - Print...
# 540  Japanese Journal of Political Science/2015 - L...
#
#                                          populism_inxs  populis*_N  \
# 0    [30, 66, 104, 122, 160, 263, 284, 310, 314, 31...         206
# 1    [26, 35, 64, 73, 124, 133, 150, 159, 214, 238,...         240
# 2    [19, 42, 57, 97, 138, 163, 377, 504, 579, 671,...         124
# 3    [65, 125, 142, 195, 225, 254, 282, 304, 313, 3...         301
# 4            [296, 2412, 4038, 4146, 4596, 4638, 4759]           7
# ..                                                 ...         ...
# 536                             [155, 238, 2478, 3747]           4
# 537  [25, 516, 526, 534, 556, 752, 1169, 1203, 1216...          24
# 538  [7, 51, 97, 316, 386, 392, 452, 649, 660, 720,...          18
# 539  [4, 59, 195, 217, 258, 878, 905, 1029, 1570, 2...          40
# 540  [16, 22, 26, 80, 95, 109, 114, 131, 153, 162, ...         293
#
#                                             conc_left1  \
# 0    [rightwing populis*, rightwing populis*, right...
# 1    [nerve populis*, more populis*, nerve populis*...
# 2    [the populis*, analytically populis*, that pop...
# 3    [of populis*, both conceptuallyandempiricallyt...
# 4    [euroscepticism populis*, on populis*, on popu...
# ..                                                 ...
# 536  [illiberal populis*, of populis*, often populi...
# 537  [the populis*, new populis*, old populis*, the...
# 538  [antieuropean populis*, antieuropean populis*,...
# 539  [people populis*, this populis*, nationalism p...
# 540  [japanese populis*, european populis*, studies...
#
#                                            conc_right1
# 0    [populis* leaders, populis* leaders, populis* ...
# 1    [populis* news, populis* reader, populis* news...
# 2    [populis* and, populis* and, populis* and, pop...
# 3    [populis* attitudes, conceptuallyandempiricall...
# 4    [populis* secondorder, populis* and, populis* ...
# ..                                                 ...
# 536  [populis* it, populis* pis, populis* and, popu...
# 537  [populis* turn, populis* bears, populis* of, p...
# 538  [populis* are, populis* in, populis* backlash,...
# 539  [populis* photography, populis* nationalism, p...
# 540  [populis* research, populis* radical, populis*...
#
# [539 rows x 11 columns]

# %%
conc_left1_all = []
for conc_list in articles_metadata["conc_left1"]:
    conc_left1_all.extend(conc_list)

# %%
len(conc_left1_all)
# Out:
# 42174

# %%
conc_left1_all_df = pd.DataFrame(nltk.FreqDist(conc_left1_all).most_common(), columns=["conc", "count"])
conc_left1_all_df[:100]
# Out:
#                       conc  count
# 0              of populis*   7793
# 1             the populis*   3216
# 2       rightwing populis*   1703
# 3            that populis*   1411
# 4               a populis*   1372
# ..                     ...    ...
# 95      illiberal populis*     38
# 96  transnational populis*     38
# 97           such populis*     37
# 98        however populis*     37
# 99      different populis*     37
#
# [100 rows x 2 columns]

# %%
#google_conf.set_with_dataframe(pop_data.add_worksheet("conc_left1", 1,1), conc_left1_all_df)

# %%
conc_left1_interesting = ['rightwing populis*', 'leftwing populis*', 'right populis*',  'left populis*', 'radical populis*', 'authoritarian populis*', 'class populis*',  'exclusionary populis*', 'economic populis*', 'leftist populis*', 'political populis*', 'radicalright populis*']
conc_left1_interesting
# Out:
# ['rightwing populis*',
#  'leftwing populis*',
#  'right populis*',
#  'left populis*',
#  'radical populis*',
#  'authoritarian populis*',
#  'class populis*',
#  'exclusionary populis*',
#  'economic populis*',
#  'leftist populis*',
#  'political populis*',
#  'radicalright populis*']

# %%
conc_left1_interesting_df = conc_left1_all_df[conc_left1_all_df["conc"].isin(conc_left1_interesting)]
conc_left1_interesting_df
# Out:
#                       conc  count
# 2       rightwing populis*   1703
# 13       leftwing populis*    400
# 16          right populis*    237
# 20           left populis*    192
# 33  authoritarian populis*    103
# 41   exclusionary populis*     91
# 42          class populis*     86
# 44        radical populis*     84
# 57       economic populis*     68
# 63      political populis*     61
# 64        leftist populis*     60
# 75   radicalright populis*     53

# %%
#google_conf.set_with_dataframe(pop_data.add_worksheet("conc_left1_interesting",1,1), conc_left1_interesting_df)

# %%
def ectract_counts_of_interesting(list_of_concs):
    conc_count_dict = dict([(conc, list_of_concs.count(conc)) for conc in conc_left1_interesting])
    return conc_count_dict
articles_metadata["conc_left1_interesting"] = articles_metadata["conc_left1"].apply(ectract_counts_of_interesting)

# %%
articles_metadata.head(20)
# Out:
#     pop_id  year                 authors  \
# 0        0  2011              Bos et al.
# 1        1  2019         Blassnig et al.
# 2        2  2017                Caramani
# 3        3  2020  Wuttke,Schimpf, Schoen
# 4        4  2014                   Treib
# 5        5  2016                  Hobolt
# 6        6  2018          Kreuder-Sonnen
# 7        7  2019       McDonnell, Werner
# 8        8  2019                 Schmidt
# 9        9  2020           Bakker et al.
# 10      10  2020           Bisbee et al.
# 11      11  2020                Escartin
# 12      12  2020      Spencer, Oppermann
# 13      13  2018                Lockwood
# 14      14  2020                   Huber
# 15      15  2018                 Hurrell
# 16      16  2015        Verbeek, Zaslove
# 17      17  2018                Rooduijn
# 18      18  2018            Bobba et al.
# 19      19  2018        Hameleers et al.
#
#                                         journal  \
# 0                       Political Communication
# 1                       Political Communication
# 2             American Political Science Review
# 3             American Political Science Review
# 4             Journal of European Public Policy
# 5             Journal of European Public Policy
# 6             Journal of European Public Policy
# 7             Journal of European Public Policy
# 8             Journal of European Public Policy
# 9             Journal of European Public Policy
# 10            Journal of European Public Policy
# 11            Journal of European Public Policy
# 12            Journal of European Public Policy
# 13                       Environmental Politics
# 14                       Environmental Politics
# 15               Ethics & International Affairs
# 16            European Political Science Review
# 17            European Political Science Review
# 18  The International Journal of Press/Politics
# 19  The International Journal of Press/Politics
#
#                                                 title     type  \
# 0   How the Media Shape Perceptions of Right-Wing ...  article
# 1   Hitting a Nerve: Populist News Articles Lead t...  article
# 2   Will vs. Reason: The Populist and Technocratic...  article
# 3   When the Whole Is Greater than the Sum of Its ...  article
# 4   The voter says no, but nobody listens: causes ...  article
# 5   The Brexit vote: a divided nation, a divided c...  article
# 6   An authoritarian turn in Europe and European S...  article
# 7   Differently Eurosceptic: radical right populis...  article
# 8   Politicization in the EU: between national pol...  article
# 9   Multidimensional incongruence, political disaf...  article
# 10  Decompensating domestically: the political eco...  article
# 11  Populist challenges to EU foreign policy in th...  article
# 12  Narrative genres of Brexit: the Leave campaign...  article
# 13  Right-wing populism and the climate change age...  article
# 14  The role of populist attitudes in explaining c...  article
# 15  Beyond the BRICS: Power, Pluralism, and the Fu...  article
# 16  The impact of populist radical right parties o...  article
# 17  What unites the voter bases of populist partie...  article
# 18  Populism and the Gender Gap: Comparing Digital...  article
# 19  Start Spreading the News: A Comparative Experi...  article
#
#                                              filepath  \
# 0   Political Communication/2011 - Bos et al. - Ho...
# 1   Political Communication/2019 - Blassing et al....
# 2   American Political Science Review/2017 - Caram...
# 3   American Political Science Review/2020 - Wuttk...
# 4   Journal of European Public Policy/2014 - Treib...
# 5   Journal of European Public Policy/2016 - Hobol...
# 6   Journal of European Public Policy/2018 - Kreud...
# 7   Journal of European Public Policy/2019 - McDon...
# 8   Journal of European Public Policy/2019 - Schmi...
# 9   Journal of European Public Policy/2020 - Bakke...
# 10  Journal of European Public Policy/2020 - Bisbe...
# 11  Journal of European Public Policy/2020 - Escar...
# 12  Journal of European Public Policy/2020 - Spenc...
# 13  Environmental Politics/2018 - Lockwood - Right...
# 14  Environmental Politics/2020 - Huber - The role...
# 15  Ethics & International Affairs/2018 - Hurrell ...
# 16  European Political Science Review/2014 - Verbe...
# 17  European Political Science Review/2018 - Roodu...
# 18  International Journal of Press-Politics/2018 -...
# 19  International Journal of Press-Politics/2018 -...
#
#                                         populism_inxs  populis*_N  \
# 0   [30, 66, 104, 122, 160, 263, 284, 310, 314, 31...         206
# 1   [26, 35, 64, 73, 124, 133, 150, 159, 214, 238,...         240
# 2   [19, 42, 57, 97, 138, 163, 377, 504, 579, 671,...         124
# 3   [65, 125, 142, 195, 225, 254, 282, 304, 313, 3...         301
# 4           [296, 2412, 4038, 4146, 4596, 4638, 4759]           7
# 5   [241, 603, 805, 1028, 3348, 3382, 3939, 4786, ...          16
# 6   [204, 266, 616, 627, 746, 776, 1822, 2457, 260...          23
# 7   [30, 54, 101, 128, 279, 292, 342, 379, 514, 63...          27
# 8   [142, 302, 529, 699, 1582, 2086, 2174, 2241, 2...          14
# 9   [284, 1165, 1595, 1717, 1792, 3403, 3435, 3443...          13
# 10  [147, 270, 584, 924, 1454, 1468, 1523, 1546, 1...          12
# 11  [24, 50, 100, 122, 169, 203, 251, 282, 300, 38...          16
# 12  [277, 283, 296, 6574, 6616, 6629, 6640, 6666, ...          12
# 13  [24, 43, 85, 109, 164, 176, 257, 264, 510, 594...          53
# 14  [24, 50, 115, 188, 196, 246, 257, 728, 793, 81...         143
# 15   [1015, 2321, 2818, 2845, 3094, 3124, 3253, 3287]           8
# 16  [3, 37, 286, 287, 296, 782, 1189, 1301, 1302, ...          24
# 17  [6, 13, 32, 86, 93, 112, 131, 166, 172, 188, 2...         187
# 18  [23, 32, 34, 61, 89, 91, 164, 170, 173, 179, 1...         177
# 19  [34, 107, 132, 182, 192, 221, 229, 256, 264, 2...         172
#
#                                            conc_left1  \
# 0   [rightwing populis*, rightwing populis*, right...
# 1   [nerve populis*, more populis*, nerve populis*...
# 2   [the populis*, analytically populis*, that pop...
# 3   [of populis*, both conceptuallyandempiricallyt...
# 4   [euroscepticism populis*, on populis*, on popu...
# 5   [euroscepticism populis*, of populis*, the pop...
# 6   [nationalist populis*, legitimacy populis*, na...
# 7   [right populis*, right populis*, right populis...
# 8   [euroskeptic populis*, commission populis*, by...
# 9   [representation populis*, for populis*, for po...
# 10  [of populis*, keywords populis*, farright popu...
# 11  [httpswwwtandfonlinecomloirjpp populis*,  popu...
# 12  [and populis*, enables populis*, brexit populi...
# 13  [rightwing populis*, rightwing populis*, right...
# 14  [of populis*, of populis*, of populis*, betwee...
# 15  [and populis*, propelled populis*nationalism, ...
# 16  [of populis*, the populis*, policy populis*, p...
# 17  [of populis*,  populis*, european populis*, ab...
# 18  [article populis*, with populis*, and nonpopul...
# 19  [of populis*, although populis*, of populis*, ...
#
#                                           conc_right1  \
# 0   [populis* leaders, populis* leaders, populis* ...
# 1   [populis* news, populis* reader, populis* news...
# 2   [populis* and, populis* and, populis* and, pop...
# 3   [populis* attitudes, conceptuallyandempiricall...
# 4   [populis* secondorder, populis* and, populis* ...
# 5   [populis* referendum, populis* parties, populi...
# 6   [populis* have, populis* introduction, populis...
# 7   [populis* parties, populis* parties, populis* ...
# 8   [populis* or, populis* eurozone, populis* chal...
# 9   [populis* research, populis* radical, populis*...
# 10  [populis* across, populis* free, populis* part...
# 11  [populis* challenges, populis* challenges, pop...
# 12  [populis* narratives, populis* to, populis* it...
# 13  [populis* and, populis* and, populis* and, pop...
# 14  [populis* attitudes, populis* attitudes, popul...
# 15  [populis* nationalism, populis*nationalism and...
# 16  [populis* radical, populis* radical, populis* ...
# 17  [populis* parties, populis* parties, populis* ...
# 18  [populis* and, populis* and, nonpopulis* faceb...
# 19  [populis* communication, populis* communicatio...
#
#                                conc_left1_interesting
# 0   {'rightwing populis*': 122, 'leftwing populis*...
# 1   {'rightwing populis*': 3, 'leftwing populis*':...
# 2   {'rightwing populis*': 2, 'leftwing populis*':...
# 3   {'rightwing populis*': 0, 'leftwing populis*':...
# 4   {'rightwing populis*': 0, 'leftwing populis*':...
# 5   {'rightwing populis*': 0, 'leftwing populis*':...
# 6   {'rightwing populis*': 2, 'leftwing populis*':...
# 7   {'rightwing populis*': 1, 'leftwing populis*':...
# 8   {'rightwing populis*': 0, 'leftwing populis*':...
# 9   {'rightwing populis*': 0, 'leftwing populis*':...
# 10  {'rightwing populis*': 6, 'leftwing populis*':...
# 11  {'rightwing populis*': 1, 'leftwing populis*':...
# 12  {'rightwing populis*': 0, 'leftwing populis*':...
# 13  {'rightwing populis*': 9, 'leftwing populis*':...
# 14  {'rightwing populis*': 6, 'leftwing populis*':...
# 15  {'rightwing populis*': 0, 'leftwing populis*':...
# 16  {'rightwing populis*': 0, 'leftwing populis*':...
# 17  {'rightwing populis*': 0, 'leftwing populis*':...
# 18  {'rightwing populis*': 1, 'leftwing populis*':...
# 19  {'rightwing populis*': 14, 'leftwing populis*'...

# %% [markdown]
# # Temporal overview

# %%
pop_id = 99

# %%
def get_split_text(pop_id):
    path = "../data/large_data/articles_filteredtexts/"
    filename = "filteredtext_pop_id_{}.txt".format(str(pop_id))
    with open(path + filename, "r") as f:
        filteredtext = f.read()
    return filteredtext.split()

def get_len(pop_id):
    path = "../data/large_data/articles_filteredtexts/"
    filename = "filteredtext_pop_id_{}.txt".format(str(pop_id))
    with open(path + filename, "r") as f:
        filteredtext = f.read()
    return len(filteredtext.split())

# %%
print(get_split_text(507))
# Out:
# ['Full', 'Terms', '&', 'Conditions', 'of', 'access', 'and', 'use', 'can', 'be', 'found', 'at', 'https://www.tandfonline.com/action/journalInformation?journalCode=rcri20', 'Critical', 'Review', 'A', 'Journal', 'of', 'Politics', 'and', 'Society', 'ISSN:', '(Print)', '(Online)', 'Journal', 'homepage:', 'https://www.tandfonline.com/loi/rcri20', 'Brexit,', 'Positional', 'Populism,', 'and', 'the', 'Declining', 'Appeal', 'of', 'Valence', 'Politics', 'Colin', 'Hay', '&', 'Cyril', 'Benoît', 'To', 'cite', 'this', 'article:', 'Colin', 'Hay', '&', 'Cyril', 'Benoît', '(2019)', 'Brexit,', 'Positional', 'Populism,', 'and', 'the', 'Declining', 'Appeal', 'of', 'Valence', 'Politics,', 'Critical', 'Review,', '31:-4,', '389-404,', 'DOI:', '10./08913811..', 'Published', 'online:', '10', 'Aug', '2020.', 'Submit', 'your', 'article', 'to', 'this', 'journal', 'Article', 'views:', '623', 'View', 'related', 'articles', 'View', 'Crossmark', 'data', 'Citing', 'articles:', '1', 'View', 'citing', 'articles', 'Colin', 'Hay', 'and', 'Cyril', 'Benoît', 'BREXIT,', 'POSITIONAL', 'POPULISM,', 'AND', 'THE', 'DECLINING', 'APPEAL', 'OF', 'VALENCE', 'POLITICS', 'ABSTRACT:', 'A', 'factor', 'that', 'may', 'account', 'for', 'the', 'largely', 'unanticipated', 'victory', 'of', 'Brexit', 'in', '\uf645\uf643\uf644\uf649', 'is', 'the', 'difference', 'in', 'engagement,', 'mobilization,', 'and,', 'ultimately,', 'turnout', 'between', 'those', 'for', 'whom', 'the', 'question', 'of', 'Brexit', 'was', 'a', 'valence', 'issue', '(a', 'dry', 'and', 'almost', 'technical', 'question', 'of', 'determining', 'the', 'policies', 'by', 'which', 'uncontroversial', 'shared', 'ends', 'can', 'be', 'achieved)', 'and', 'those', 'for', 'whom', 'it', 'was', 'a', 'positional', 'issue', '(a', 'question', 'of', 'raw,', 'almost', 'visceral,', 'political', 'preference).', 'The', 'declining', 'appeal', 'of', 'valence', 'politics', 'may', 'reveal', 'a', 'phenomenon', 'that', 'goes', 'beyond', 'Brexit', 'and', 'Britain:', 'a', 'change', 'in', 'the', 'nature', 'and', 'character', 'of', 'contemporary', 'electoral', 'competition', 'that', 'may', 'help', 'to', 'explain', 'the', 'newly', 'resurgent', 'populism', 'characteristic', 'of', 'Western', 'liberal', 'democracies.', 'Keywords:', 'Brexit;', 'populism;', 'valence', 'politics;', 'valence', 'issues;', 'positional', 'politics;', 'positional', 'issues;', 'positional', 'populism;', 'post-neoliberalism;', 'political', 'economy;', 'public', 'opinion.', 'Future', 'political', 'analysts', 'will', 'certainly', 'regard', 'the', '\uf645\uf646rd', 'day', 'of', 'June,', '\uf645\uf643\uf644\uf649,', 'as', 'a', 'milestone', 'in', 'the', 'history', 'of', 'the', 'United', 'Kingdom.', 'Forty-four', 'years', 'after', 'the', 'European', 'Communities', 'Act', 'of', '\uf644\uf64c\uf64a\uf645,', 'through', 'which', 'the', 'British', 'Parliament', 'ratiﬁed', 'the', 'Treaty', 'of', 'Accession', 'to', 'the', 'European', 'Economic', 'Colin', 'Hay,', 'colin.hay@sciencepo.fr,', 'Centre', 'd’études', 'européennes', 'de', 'Sciences', 'Po,', '\uf645\uf64a', 'rue', 'Saint', 'Guillaume,', '\uf64a\uf648\uf646\uf646\uf64a', 'Paris', 'cedex', '\uf643\uf64a', 'France,', 'is', 'Professor', 'and', 'Director', 'of', 'Doctoral', 'Studies', 'in', 'Political', 'Sciences', 'at', 'Sciences', 'Po,', 'and', 'founding', 'Co-Director', 'of', 'the', 'Shefﬁeld', 'Political', 'Economy', 'Research', 'Institute', '(SPERI)', 'at', 'the', 'University', 'of', 'Shefﬁeld.', 'Cyril', 'Benoît,', 'cyril.benoit\uf644@sciencespo.fr,', 'Centre', 'd’études', 'européennes', 'de', 'Sciences', 'Po,', '\uf645\uf64a', 'rue', 'Saint', 'Guillaume,', '\uf64a\uf648\uf646\uf646\uf64a', 'Paris', 'cedex', '\uf643\uf64a', 'France,', 'is', 'CNRS', 'Researcher', 'at', 'the', 'Centre', 'd’études', 'européennes', 'et', 'de', 'politique', 'comparée,', 'Sciences', 'Po.', 'Community', '(EEC),', '\uf648\uf644.\uf64c', 'percent', 'of', 'British', 'citizens', 'voted', 'to', 'leave', 'the', 'European', 'Union', 'into', 'which', 'the', 'EEC', 'had' ...

# %%
len(get_split_text(507))
# Out:
# 5191

# %%
articles_metadata["wordcount"] = articles_metadata["pop_id"].apply(get_len)

# %%
articles_metadata.sort_values("wordcount")
# Out:
#      pop_id  year                 authors  \
# 393     393  2017         Breuilly et al.
# 224     224  2015           Kettell, Kerr
# 396     396  2019         Breuilly et al.
# 241     241  2016          Ardoin, Gronke
# 225     225  2015                Wellings
# ..      ...   ...                     ...
# 290     290  2020     Fornaro, Kaihovaara
# 103     103  2019  Golec de Zavala et al.
# 211     211  2020               Thornhill
# 506     506  2019                Friedman
# 513     513  2014               Rothstein
#
#                                        journal  \
# 393                    Nations and Nationalism
# 224                           British Politics
# 396                    Nations and Nationalism
# 241         PS: Political Science and Politics
# 225                           British Politics
# ..                                         ...
# 290      European Journal of Political Economy
# 103                       Political Psychology
# 211                       International Theory
# 506                            Critical Review
# 513  Studies in American Political Development
#
#                                                  title       type  \
# 393                                          Editorial  editorial
# 224                                          Editorial  editorial
# 396                                          Editorial  editorial
# 241                                    EDITORS’ CORNER    article
# 225             English Nationalism And Euroscepticism    article
# ..                                                 ...        ...
# 290  Microdynamics, granularity and populism: The F...    article
# 103  Collective Narcissism: Political Consequences ...    article
# 211  Constitutionalism and populism: national polit...    article
# 506                           Populists as Technocrats    article
# 513  Macune’s Monopoly: Economic Law and the Legacy...    article
#
#                                               filepath  \
# 393  Nations and Nationalism/2017 - Breuilly et al....
# 224  British Politics/2015 - Kettell, Kerr - Editor...
# 396  Nations and Nationalism/2019 - Breuilly et al....
# 241  PS political science and politics journal/2016...
# 225  British Politics/2015 - Wellings - English Nat...
# ..                                                 ...
# 290  European Journal of Political Economy/2020 - F...
# 103  Political Psychology/2019 - Golec de Zavala et...
# 211  International Theory/2020 - Thornhill - Consti...
# 506  Critical Review/2019 - Friedman - Populists as...
# 513  Studies in American Political Development/2014...
#
#                                          populism_inxs  populis*_N  \
# 393                                              [219]           1
# 224                                              [293]           1
# 396                                         [134, 268]           2
# 241                                              [597]           1
# 225  [297, 536, 556, 561, 585, 641, 658, 921, 1005,...          12
# ..                                                 ...         ...
# 290  [24, 65, 92, 108, 111, 125, 152, 161, 180, 205...         200
# 103  [202, 324, 767, 858, 4584, 4599, 9053, 10234, ...          28
# 211  [2, 48, 69, 126, 166, 185, 188, 230, 740, 741,...         119
# 506  [27, 39, 80, 87, 99, 112, 151, 214, 264, 275, ...         221
# 513  [8, 20, 95, 472, 496, 581, 665, 715, 724, 736,...         145
#
#                                             conc_left1  \
# 393                             [nationalism populis*]
# 224                             [nationalism populis*]
# 396                    [between populis*, on populis*]
# 241                              [democratic populis*]
# 225  [left populis*, their populis*, it populis*, i...
# ..                                                 ...
# 290  [and populis*, churning populis*, to populis*,...
# 103  [of populis*, hostility populis*, of populis*,...
# 211  [and populis*, on populis*, many populis*, whi...
# 506  [httpswwwtandfonlinecomloircri populis*,  popu...
# 513  [of populis*, the populis*, association populi...
#
#                                            conc_right1  \
# 393                        [populis* authoritarianism]
# 224                                   [populis* party]
# 396                       [populis* and, populis* and]
# 241                                      [populis* as]
# 225  [populis* of, populis* antagonism, populis* is...
# ..                                                 ...
# 290  [populis* the, populis* granularity, populis* ...
# 103  [populis* rhetoric, populis* selfesteem, popul...
# 211  [populis* national, populis* government, popul...
# 506  [populis* as, populis* as, populis* might, pop...
# 513  [populis* sidney, populis* legacy, populis* di...
#
#                                 conc_left1_interesting  wordcount
# 393  {'rightwing populis*': 0, 'leftwing populis*':...        342
# 224  {'rightwing populis*': 0, 'leftwing populis*':...        375
# 396  {'rightwing populis*': 0, 'leftwing populis*':...        581
# 241  {'rightwing populis*': 0, 'leftwing populis*':...       1028
# 225  {'rightwing populis*': 0, 'leftwing populis*':...       1776
# ..                                                 ...        ...
# 290  {'rightwing populis*': 5, 'leftwing populis*':...      17486
# 103  {'rightwing populis*': 0, 'leftwing populis*':...      17571
# 211  {'rightwing populis*': 0, 'leftwing populis*':...      18270
# 506  {'rightwing populis*': 4, 'leftwing populis*':...      22783
# 513  {'rightwing populis*': 0, 'leftwing populis*':...      23057
#
# [539 rows x 13 columns]

# %%
articles_metadata.sort_values("wordcount", ascending=False)
# Out:
#      pop_id  year                 authors  \
# 513     513  2014               Rothstein
# 506     506  2019                Friedman
# 211     211  2020               Thornhill
# 103     103  2019  Golec de Zavala et al.
# 290     290  2020     Fornaro, Kaihovaara
# ..      ...   ...                     ...
# 225     225  2015                Wellings
# 241     241  2016          Ardoin, Gronke
# 396     396  2019         Breuilly et al.
# 224     224  2015           Kettell, Kerr
# 393     393  2017         Breuilly et al.
#
#                                        journal  \
# 513  Studies in American Political Development
# 506                            Critical Review
# 211                       International Theory
# 103                       Political Psychology
# 290      European Journal of Political Economy
# ..                                         ...
# 225                           British Politics
# 241         PS: Political Science and Politics
# 396                    Nations and Nationalism
# 224                           British Politics
# 393                    Nations and Nationalism
#
#                                                  title       type  \
# 513  Macune’s Monopoly: Economic Law and the Legacy...    article
# 506                           Populists as Technocrats    article
# 211  Constitutionalism and populism: national polit...    article
# 103  Collective Narcissism: Political Consequences ...    article
# 290  Microdynamics, granularity and populism: The F...    article
# ..                                                 ...        ...
# 225             English Nationalism And Euroscepticism    article
# 241                                    EDITORS’ CORNER    article
# 396                                          Editorial  editorial
# 224                                          Editorial  editorial
# 393                                          Editorial  editorial
#
#                                               filepath  \
# 513  Studies in American Political Development/2014...
# 506  Critical Review/2019 - Friedman - Populists as...
# 211  International Theory/2020 - Thornhill - Consti...
# 103  Political Psychology/2019 - Golec de Zavala et...
# 290  European Journal of Political Economy/2020 - F...
# ..                                                 ...
# 225  British Politics/2015 - Wellings - English Nat...
# 241  PS political science and politics journal/2016...
# 396  Nations and Nationalism/2019 - Breuilly et al....
# 224  British Politics/2015 - Kettell, Kerr - Editor...
# 393  Nations and Nationalism/2017 - Breuilly et al....
#
#                                          populism_inxs  populis*_N  \
# 513  [8, 20, 95, 472, 496, 581, 665, 715, 724, 736,...         145
# 506  [27, 39, 80, 87, 99, 112, 151, 214, 264, 275, ...         221
# 211  [2, 48, 69, 126, 166, 185, 188, 230, 740, 741,...         119
# 103  [202, 324, 767, 858, 4584, 4599, 9053, 10234, ...          28
# 290  [24, 65, 92, 108, 111, 125, 152, 161, 180, 205...         200
# ..                                                 ...         ...
# 225  [297, 536, 556, 561, 585, 641, 658, 921, 1005,...          12
# 241                                              [597]           1
# 396                                         [134, 268]           2
# 224                                              [293]           1
# 393                                              [219]           1
#
#                                             conc_left1  \
# 513  [of populis*, the populis*, association populi...
# 506  [httpswwwtandfonlinecomloircri populis*,  popu...
# 211  [and populis*, on populis*, many populis*, whi...
# 103  [of populis*, hostility populis*, of populis*,...
# 290  [and populis*, churning populis*, to populis*,...
# ..                                                 ...
# 225  [left populis*, their populis*, it populis*, i...
# 241                              [democratic populis*]
# 396                    [between populis*, on populis*]
# 224                             [nationalism populis*]
# 393                             [nationalism populis*]
#
#                                            conc_right1  \
# 513  [populis* sidney, populis* legacy, populis* di...
# 506  [populis* as, populis* as, populis* might, pop...
# 211  [populis* national, populis* government, popul...
# 103  [populis* rhetoric, populis* selfesteem, popul...
# 290  [populis* the, populis* granularity, populis* ...
# ..                                                 ...
# 225  [populis* of, populis* antagonism, populis* is...
# 241                                      [populis* as]
# 396                       [populis* and, populis* and]
# 224                                   [populis* party]
# 393                        [populis* authoritarianism]
#
#                                 conc_left1_interesting  wordcount
# 513  {'rightwing populis*': 0, 'leftwing populis*':...      23057
# 506  {'rightwing populis*': 4, 'leftwing populis*':...      22783
# 211  {'rightwing populis*': 0, 'leftwing populis*':...      18270
# 103  {'rightwing populis*': 0, 'leftwing populis*':...      17571
# 290  {'rightwing populis*': 5, 'leftwing populis*':...      17486
# ..                                                 ...        ...
# 225  {'rightwing populis*': 0, 'leftwing populis*':...       1776
# 241  {'rightwing populis*': 0, 'leftwing populis*':...       1028
# 396  {'rightwing populis*': 0, 'leftwing populis*':...        581
# 224  {'rightwing populis*': 0, 'leftwing populis*':...        375
# 393  {'rightwing populis*': 0, 'leftwing populis*':...        342
#
# [539 rows x 13 columns]

# %%
len(articles_metadata)
# Out:
# 539

# %%
journals = articles_metadata.groupby("journal").size().sort_values(ascending=False)
journals
# Out:
# journal
# Journal of Democracy                     50
# Democratization                          22
# Political Studies                        21
# The Political Quarterly                  20
# Swiss Political Science Review           17
#                                          ..
# Politics & Gender                         1
# Politics & Society                        1
# Contemporary Politics                     1
# European History Quarterly                1
# Japanese Journal of Political Science     1
# Length: 101, dtype: int64

# %%
len(journals)
# Out:
# 101

# %%
articles_metadata["wordcount"].sum()
# Out:
# 3974549

# %%
20000 * 500
# Out:
# 10000000

# %%
for year in range(2011,2021):
    subset_df = articles_metadata[articles_metadata["year"]==year]
    text_list = []
    for pop_id in subset_df["pop_id"]:
        text_list.extend(get_split_text(pop_id))
    print(year, len(text_list))
# Out:
# 2011 120091
# 2012 117687
# 2013 157127
# 2014 181029
# 2015 141973
# 2016 344168
# 2017 507879
# 2018 553672
# 2019 917675
# 2020 933248

# %%
# average length of articles
sns.barplot(data=articles_metadata, x="year", y="wordcount", color="gray")
# Out:
# <AxesSubplot: xlabel='year', ylabel='wordcount'>

# %%
articles_metadata.groupby("year").sum()
# Out:
#       pop_id  populis*_N  wordcount
# year
# 2011    3799        1197     120091
# 2012    3899         699     117687
# 2013    5725        1166     157127
# 2014    7081        2471     181029
# 2015    5764        1793     141973
# 2016   13533        3732     344168
# 2017   19202        5654     507879
# 2018   19439        6219     553672
# 2019   35716        9621     917675
# 2020   31399        9622     933248

# %%
articles_metadata["year"] = articles_metadata["year"].replace(3017, 2017)

# %%
articles_metadata_sums = articles_metadata.groupby("year").sum().reset_index()
articles_metadata_sums
# Out:
#    year  pop_id  populis*_N  wordcount
# 0  2011    3799        1197     120091
# 1  2012    3899         699     117687
# 2  2013    5725        1166     157127
# 3  2014    7081        2471     181029
# 4  2015    5764        1793     141973
# 5  2016   13533        3732     344168
# 6  2017   19202        5654     507879
# 7  2018   19439        6219     553672
# 8  2019   35716        9621     917675
# 9  2020   31399        9622     933248

# %%
articles_metadata_sums["populis*_freq"] = np.round(articles_metadata_sums["populis*_N"] / articles_metadata_sums["wordcount"], 4)

# %%
articles_metadata_sums
# Out:
#    year  pop_id  populis*_N  wordcount  populis*_freq
# 0  2011    3799        1197     120091         0.0100
# 1  2012    3899         699     117687         0.0059
# 2  2013    5725        1166     157127         0.0074
# 3  2014    7081        2471     181029         0.0136
# 4  2015    5764        1793     141973         0.0126
# 5  2016   13533        3732     344168         0.0108
# 6  2017   19202        5654     507879         0.0111
# 7  2018   19439        6219     553672         0.0112
# 8  2019   35716        9621     917675         0.0105
# 9  2020   31399        9622     933248         0.0103

# %%
cm = plt.get_cmap("Greys")
color= cm(articles_metadata_sums["populis*_freq"] / articles_metadata_sums["populis*_freq"].max())

# %%
from matplotlib.cm import ScalarMappable

# %%
fig, ax = plt.subplots(figsize=(5.7, 3), dpi=300, tight_layout=True)
ax.bar(x=articles_metadata_sums["year"], height=articles_metadata_sums["wordcount"], color=color)
ax.ticklabel_format(style='plain')
ax.set_ylabel("wordcount")
ax.set_xticks(articles_metadata_sums["year"], )
ax.set_xticklabels(articles_metadata_sums["year"], rotation=90)

sm = ScalarMappable(cmap=cm)
# set colorbar properties
sm.set_array([])
sm.set_clim(0, articles_metadata_sums["populis*_freq"].max())

# create colorbar
cbar = plt.colorbar(sm, ax=ax)

# set colorbar label
cbar.ax.set_ylabel('populis* frequency')
# Out:
# Text(0, 0.5, 'populis* frequency')

# %%
fig.savefig("../figures/wordcount_by_years_bars.png")
